# %% [markdown]
# <a href="https://colab.research.google.com/github/Lamiya-56/Sales-and-Profit-Analysis-Across-Regions-and-Categories/blob/main/Sales_and_Profit_Analysis_Across_Regions_and_Categories.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/Sample - Superstore.csv.zip', encoding='latin1')
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# Dataset 9994 sətir, 21 sütundan ibarətdir və missing value yoxdur

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])
df['Ship Date']=pd.to_datetime(df['Ship Date'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df['Order Date']
# Out:
# 0      2016-11-08
# 1      2016-11-08
# 2      2016-06-12
# 3      2015-10-11
# 4      2015-10-11
#           ...
# 9989   2014-01-21
# 9990   2017-02-26
# 9991   2017-02-26
# 9992   2017-02-26
# 9993   2017-05-04
# Name: Order Date, Length: 9994, dtype: datetime64[ns]

# %%
# Feature Engineering
df['days_to_ship'] = (df['Ship Date'] - df['Order Date']).dt.days
df['Year'] = df['Order Date'].dt.year
df['Profit Margin (%)'] = (df['Profit'] / df['Sales']) * 100
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df.groupby('Category')['Profit Margin (%)'].sum()
# Out:
# Category
# Furniture           8225.987395
# Office Supplies    83177.055556
# Technology         28838.698413
# Name: Profit Margin (%), dtype: float64

# %%
#Aggregate total Sales and Profit by: Region, Category, Sub-Category
agg_df = df.groupby(['Region', 'Category', 'Sub-Category'])[['Sales', 'Profit']].sum().reset_index()
agg_df
# Out:
#      Region         Category Sub-Category       Sales      Profit
# 0   Central        Furniture    Bookcases  24157.1768  -1997.9043
# 1   Central        Furniture       Chairs  85230.6460   6592.7221
# 2   Central        Furniture  Furnishings  15254.3700  -3906.2168
# 3   Central        Furniture       Tables  39154.9710  -3559.6504
# 4   Central  Office Supplies   Appliances  23582.0330  -2638.6175
# ..      ...              ...          ...         ...         ...
# 63     West  Office Supplies     Supplies  18127.1220    626.0465
# 64     West       Technology  Accessories  61114.1160  16484.5983
# 65     West       Technology      Copiers  49749.2420  19327.2351
# 66     West       Technology     Machines  42444.1220   -618.9264
# 67     West       Technology       Phones  98684.3520   9110.7426
#
# [68 rows x 5 columns]

# %%
#Identify top 5 and bottom 5 sub-categories by Profit

subcat_profit = df.groupby('Sub-Category')['Profit'].sum().sort_values(ascending=False)
top_5 = subcat_profit.head(5)
bottom_5 = subcat_profit.tail(5)
top_5
# Out:
# Sub-Category
# Copiers        55617.8249
# Phones         44515.7306
# Accessories    41936.6357
# Paper          34053.5693
# Binders        30221.7633
# Name: Profit, dtype: float64

# %% [markdown]
# Ən gəlirli sub-kateqoriya: Copiers (55k$ mənfəət)

# %%
bottom_5
# Out:
# Sub-Category
# Machines      3384.7569
# Fasteners      949.5182
# Supplies     -1189.0995
# Bookcases    -3472.5560
# Tables      -17725.4811
# Name: Profit, dtype: float64

# %%
region_sales = df.groupby('Region')['Sales'].sum().sort_values(ascending=False)
region_sales
# Out:
# Region
# West       725457.8245
# East       678781.2400
# Central    501239.8908
# South      391721.9050
# Name: Sales, dtype: float64

# %% [markdown]
# Ən yüksək satış: West regionu (725k), ən aşağı: South (391k)

# %%
cat_analysis = df.groupby('Category')[['Sales', 'Profit']].sum()
cat_analysis
# Out:
#                        Sales       Profit
# Category
# Furniture        741999.7953   18451.2728
# Office Supplies  719047.0320  122490.8008
# Technology       836154.0330  145454.9481

# %%
# Sub-kateqoriya üzrə mənfəət
subcat_profit = df.groupby('Sub-Category')['Profit'].sum().sort_values()

subcat_profit[subcat_profit < 0]
# Out:
# Sub-Category
# Tables      -17725.4811
# Bookcases    -3472.5560
# Supplies     -1189.0995
# Name: Profit, dtype: float64

# %% [markdown]
# Tables, Bookcases, Supplies sub-kateqoriyaları mənfi mənfəətdədir: -17k$ profit ilə ən zərərli məhsul - Tables

# %% [markdown]
# #Scatter plot of discount vs profit

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Discount', y='Profit', data=df)
plt.title('Relationship between Discount and Profit')
plt.axhline(0, color='red', linestyle='--') # 0 xəttini çəkir ki, zərəri görək
plt.show()

# %% [markdown]
# 0.4, 0.5, 0.6, 0.7 və 0.8 endirim dərəcələrində nöqtələr demək olar ki, tamamilə qırmızı kəsik xəttin (0-ın) altında toplanıb.
#
# Yüksək endirim tətbiq olunduqda, məhsulun maya dəyəri və çatdırılma xərcləri satış qiymətini üstələyir, bu da şirkətin zərərinə işləməsinə səbəb olur.

# %% [markdown]
# #Yearly sales trend line

# %%
yearly_sales = df.groupby('Year')['Sales'].sum()

plt.figure(figsize=(8, 4))
yearly_sales.plot(kind='line', marker='o', color='green')
plt.title('Year-over-year total sales')
plt.ylabel('Sales ($)')
plt.xticks(yearly_sales.index)
plt.grid(True)
plt.show()

# %%
yearly_sales
# Out:
# Year
# 2014    484247.4981
# 2015    470532.5090
# 2016    609205.5980
# 2017    733215.2552
# Name: Sales, dtype: float64

# %% [markdown]
# 2017-ci il ən yüksək satış ili olub (733k$); illik artım ~20%

# %% [markdown]
# #Bar chart of profit by sub-category (highlight negatives)

# %%
subcat_profit
# Out:
# Sub-Category
# Tables        -17725.4811
# Bookcases      -3472.5560
# Supplies       -1189.0995
# Fasteners        949.5182
# Machines        3384.7569
# Labels          5546.2540
# Art             6527.7870
# Envelopes       6964.1767
# Furnishings    13059.1436
# Appliances     18138.0054
# Storage        21278.8264
# Chairs         26590.1663
# Binders        30221.7633
# Paper          34053.5693
# Accessories    41936.6357
# Phones         44515.7306
# Copiers        55617.8249
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(10, 6))

colors = ['red' if x < 0 else 'green' for x in subcat_profit]
plt.bar(subcat_profit.index, subcat_profit.values, color=colors)
plt.xticks(rotation=45)
plt.title("Profit by Sub-Category (Red = Negative)")
plt.ylabel("Profit")
plt.show()

# %%
# --- Part 1: Calculate Profit Margin (%) per Category ---
category_data = df.groupby('Category')[['Sales', 'Profit']].sum()
category_data['Profit Margin (%)'] = (category_data['Profit'] / category_data['Sales']) * 100

# Visualize Profit Margin (%) per Category with a color-coded bar chart
plt.figure(figsize=(10, 6))
colors = sns.color_palette('viridis', len(category_data))
bars = plt.bar(category_data.index, category_data['Profit Margin (%)'], color=colors)
plt.title('Profit Margin (%) per Category')
plt.xlabel('Category')
plt.ylabel('Profit Margin (%)')

# Add labels to the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.2f}%', ha='center', va='bottom')

plt.show()

# %% [markdown]
# "Technology" və "Office Supplies" kateqoriyaları yüksək gəlirlilik nümayiş etdirsə də, "Furniture" kateqoriyasının mənfəət marjası kəskin şəkildə aşağıdır. "Furniture" sahəsində ya xərclərimizi (istehsal və daşınma) azaltmalı, ya da satış qiymətlərini yenidən tənzimləməliyik ki, qazancımız artsın. Hazırkı 2.49%-lik gəlir marjası çox aşağıdır və bu, biznesin nə dərəcədə səmərəli işlədiyini ölçən ən vacib göstəricidir.

# %%
# --- Part 2: Heatmap of Region vs Category showing total profit ---
heatmap_data = df.groupby(['Region', 'Category'])['Profit'].sum().unstack()

plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, fmt='.0f', cmap='YlGnBu')
plt.title('Total Profit: Region vs Category')
plt.xlabel('Category')
plt.ylabel('Region')
plt.savefig('heatmap_region_category.png')
plt.show()

# %% [markdown]
# Central regionunda mebel satışı zərərlə nəticələnir, bu mütləq araşdırılmalıdır. Əvəzində, West regionu ən yüksək qazanc gətirən bölgədir və Office Supplies kateqoriyası şirkətin ən stabil gəlir mənbəyidir.

# %% [markdown]
# #Business insights

# %% [markdown]
# 1. Endirimlərin tətbiqinə ciddi məhdudiyyətlərin qoyulması
#
# "Relationship between Discount and Profit" diaqramı endirim dərəcələri ilə mənfəət arasında kəskin mənfi korrelyasiyanın olduğunu göstərir. Xüsusilə 50%-dən yuxarı endirim tətbiq edildikdə, satışdan əldə olunan gəlir xərcləri qarşılamaqda yetərsiz qalır.
#
# Tədbir: Mənfəət itkisinin qarşısını almaq məqsədilə endirim siyasətinə ciddi məhdudiyyətlər tətbiq edilməlidir. Qazancı qorumaq məqsədilə 30-40%-dən çox endirim edilməsinə icazə verilməməlidir

# %% [markdown]
# 2. Mənfi mənfəət gətirən məhsulların optimallaşdırılması
#
# "Profit by Sub-Category" diaqramı "Tables" və "Bookcases" kimi bəzi alt kateqoriyaların maliyyə baxımından səmərəsiz olduğunu və ümumi mənfəətə mənfi təsir göstərdiyini aşkar edir. Bu məhsulların satışı gəlir gətirmək əvəzinə, şirkət üçün birbaşa itki ilə nəticələnir.
#
# Tədbir: Sözügedən məhsul qruplarının satışı dayandırılmalı və ya onların qiymətqoyma strategiyaları yenidən nəzərdən keçirilməlidir. Çox satmaqdan daha çox, gəlir əldə etməyə üstünlük verilməli və bu kateqoriyalarda lazımi dəyişikliklər edilməlidir.

# %% [markdown]
# 3. Satış həcmindən çox, mənfəətə fokuslanmaq
#
# İllik satışların artması müsbət haldır, lakin yüksək satış həcmi hər zaman yüksək mənfəət demək deyil. Sonda əldə olunan xalis gəlir, sadəcə satış dövriyyəsindən daha vacibdir.
#
# Tədbir: Mövcud müştəri bazasından istifadə edərək diqqət daha çox qazanc gətirən məhsulların satışına yönəldilməlidir. Bütün çeşidlər əvəzinə, xüsusilə "Copiers", "Phones" və "Accessories" kimi yüksək mənfəətli kateqoriyalar ön plana çıxarılmalıdır.

# %% [markdown]
# 4. Resursların ən gəlirli məhsullara yönəldilməsi
#
# "Copiers", "Phones" və "Accessories" kateqoriyaları yüksək gəlirlilik nümayiş etdirərək biznesin "ulduz" məhsulları kimi müəyyən edilmişdir. Buna qarşılıq olaraq, "Tables" və bənzəri aşağı gəlirli məhsullar resursların səmərəsiz xərclənməsinə səbəb olur.
#
# Tədbir: Reklam büdcəsi, vaxt və digər əməliyyat resursları zərər gətirən kateqoriyalardan ayrılaraq, tamamilə yüksək mənfəətli "Copiers", "Phones" və "Accessories" məhsullarına yönəldilməlidir. Bu optimallaşdırma ümumi mənfəəti artırmaq üçün həlledici yoldur.
